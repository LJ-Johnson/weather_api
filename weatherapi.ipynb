# %%
baseurl = "http://api.weatherapi.com/v1"

# %%
LJ_key = '50ac5b8ebf1a47e9bc5213239252512'

# %%
 # JSON: http://api.weatherapi.com/v1/current.json?key=<YOUR_API_KEY>&q=London

# %%
import requests
import pandas as pd

# %%
city = "lexington"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={LJ_key}&q={'lexington'}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Lexington-Fayette',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.0497,
#   'lon': -84.4586,
#   'tz_id': 'America/New_York',
#   'localtime_epoch': 1767728346,
#   'localtime': '2026-01-06 14:39'},
#  'current': {'last_updated_epoch': 1767727800,
#   'last_updated': '2026-01-06 14:30',
#   'temp_c': 13.3,
#   'temp_f': 55.9,
#   'is_day': 1,
#   'condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'wind_mph': 19.7,
#   'wind_kph': 31.7,
#   'wind_degree': 228,
#   'wind_dir': 'SW',
#   'pressure_mb': 1006.0,
#   'pressure_in': 29.7,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 84,
#   'cloud': 100,
#   'feelslike_c': 10.8,
#   'feelslike_f': 51.4,
#   'windchill_c': 10.6,
#   'windchill_f': 51.1,
#   'heatindex_c': 13.0,
#   'heatindex_f': 55.4,
#   'dewpoint_c': 10.9,
#   'dewpoint_f': 51.7,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 0.5,
#   'gust_mph': 28.4,
#   'gust_kph': 45.6,
#   'short_rad': 61.06,
#   'diff_rad': 36.76,
#   'dni': 0.0,
#   'gti': 34.15}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (55.9, 84)

# %%
def get_weather(city):
    url= f"http://api.weatherapi.com/v1/current.json?key={LJ_key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print(f"Weather for {location['name']},{location['region']}")
        print(f"Temperature: {current['temp_f']} F/ {current['temp_c']} C/")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']}mph")
    else:
        print(f"Error fetching data for{city}: {response.status_code}")

# %%
get_weather("west memphis")
# Out:
# Weather for West Memphis,Arkansas
# Temperature: 69.1 F/ 20.6 C/
# Condition: Partly Cloudy
# Humidity: 65%
# Wind Speed: 11.9mph

# %%
get_weather("colorado springs")
# Out:
# Weather for Colorado Springs,Colorado
# Temperature: 48.9 F/ 9.4 C/
# Condition: Sunny
# Humidity: 19%
# Wind Speed: 5.1mph

# %%
cities = ["colorado springs", "lexington", "Oymyakon", 
          "Phoenix"]
weather_data = []

for city in cities:
    url = f"http://api.weatherapi.com/v1/current.json?key={LJ_key}&q={city}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        weather_data.append({
            "City" : data['location']['name'],
            "temerature": data['current']['temp_f'],
            "Condition": data ['current']['condition'],
            "humidity" : data['current']['humidity'],
            "Wind Speed": data ['current']['wind_mph'] })
    else:
        print("Error fetching data")

# %%
weather_data
# Out:
# [{'City': 'Colorado Springs',
#   'temerature': 48.9,
#   'Condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'humidity': 19,
#   'Wind Speed': 5.1},
#  {'City': 'Lexington-Fayette',
#   'temerature': 55.9,
#   'Condition': {'text': 'Overcast',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#    'code': 1009},
#   'humidity': 84,
#   'Wind Speed': 19.7},
#  {'City': 'Oymyakon',
#   'temerature': -26.0,
#   'Condition': {'text': 'Light snow',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/326.png',
#    'code': 1213},
#   'humidity': 97,
#   'Wind Speed': 2.2},
#  {'City': 'Phoenix',
#   'temerature': 63.0,
#   'Condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'humidity': 50,
#   'Wind Speed': 4.3}]

# %%
weather_df = pd.DataFrame(weather_data)

# %%
weather_df.head()
# Out:
#                 City  temerature  \
# 0   Colorado Springs        48.9
# 1  Lexington-Fayette        55.9
# 2           Oymyakon       -26.0
# 3            Phoenix        63.0
#
#                                            Condition  humidity  Wind Speed
# 0  {'text': 'Sunny', 'icon': '//cdn.weatherapi.co...        19         5.1
# 1  {'text': 'Overcast', 'icon': '//cdn.weatherapi...        84        19.7
# 2  {'text': 'Light snow', 'icon': '//cdn.weathera...        97         2.2
# 3  {'text': 'Partly cloudy', 'icon': '//cdn.weath...        50         4.3
